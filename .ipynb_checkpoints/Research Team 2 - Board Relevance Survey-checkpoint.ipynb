# %% [markdown]
# # Import neccessary Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Details of the data

# %%
file_path = 'data/Detail.txt'

# Open and read the text file
with open(file_path, 'r') as file:
    content = file.read()

# Print or use the content as needed
print(content)
# Out:
# GENDER - Gender of the respondent (Male, Female, Other).
#
# AGE_RANGE - Age group of the respondent (e.g., 18-24, 25-34, 35-44, 45+).
#
# EDUCATION_LEVEL - The highest level of education completed by the respondent (e.g., High School, Bachelor's, Master's, Ph.D.).
#
# USE_JOB_BOARDS - Frequency of using job boards for job searches (e.g., Daily, Weekly, Rarely, Never).
#
# USED_JOB_BOARDS - List of specific job boards or online platforms used during job searches.
#
# OTHER_JOB_SOURCES - Other sources used for job searches apart from job boards.
#
# INTERESTED_INDUSTRIES - Industries or sectors of interest when using job boards for job searches (comma-separated list).
#
# SUCCESS_WITH_JOB_BOARDS - Perceived success of job boards in connecting with relevant job opportunities (e.g., 1-10 scale).
#
# EMPLOYMENT_THROUGH_JOB_BOARD - Whether the respondent has secured employment through a job board (Yes/No).
#
# ...

# %% [markdown]
# # Load the data

# %%
dfu = pd.read_csv("updated_file.csv")

# %%
dfu
# Out:
#                      TIMESTAMP  GENDER AGE RANGE          EDUCATION LEVEL  \
# 0   2023/08/07 12:26:18 PM GMT    Male     25-34        Bachelor's Degree
# 1   2023/08/07 12:49:12 PM GMT    Male     18-24        Bachelor's Degree
# 2   2023/08/07 12:49:30 PM GMT  Female     18-24        Bachelor's Degree
# 3    2023/08/09 1:15:12 PM GMT  Female     18-24        Bachelor's Degree
# 4   2023/08/10 10:19:46 AM GMT    Male     18-24        Bachelor's Degree
# ..                         ...     ...       ...                      ...
# 75   2023/08/16 4:12:19 PM GMT    Male     25-34        Bachelor's Degree
# 76   2023/08/16 4:17:05 PM GMT    Male     25-34  Higher National Diploma
# 77   2023/08/16 6:10:27 PM GMT  Female     18-24        Bachelor's Degree
# 78   2023/08/17 7:21:28 AM GMT  Female     18-24        Bachelor's Degree
# 79   2023/08/17 9:50:59 AM GMT    Male     25-34        Bachelor's Degree
#
#    JOB BOARD USAGE FREQUENCY                          USED JOB BOARDS  \
# ...

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# **Droping the Timestamp Column**

# %%
dfu = dfu.drop("TIMESTAMP", axis=1)

# %%
#Hadling excess spaces for strings
dfu = dfu.apply(lambda x: x.str.strip() if x.dtype=="object" else x)

# %%
#Replace instances of S.H.S to SHS on "EDUCATIONAL LEVEL" feature
dfu['EDUCATION LEVEL'] = dfu['EDUCATION LEVEL'].str.replace('S.H.S','SHS')
# Out:
# C:\Users\AgoCoded\AppData\Local\Temp\ipykernel_11052\499281425.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   dfu['EDUCATION LEVEL'] = dfu['EDUCATION LEVEL'].str.replace('S.H.S','SHS')

# %%
dfu.head()
# Out:
#    GENDER AGE RANGE    EDUCATION LEVEL JOB BOARD USAGE FREQUENCY  \
# 0    Male     25-34  Bachelor's Degree           Rarely or never
# 1    Male     18-24  Bachelor's Degree                    Weekly
# 2  Female     18-24  Bachelor's Degree           Rarely or never
# 3  Female     18-24  Bachelor's Degree           Rarely or never
# 4    Male     18-24  Bachelor's Degree                     Daily
#
#                            USED JOB BOARDS  \
# 0                                 LinkedIn
# 1                                 LinkedIn
# 2                                 LinkedIn
# 3  Bright Network and Opportunities Corner
# 4                                 LinkedIn
#
#              OTHER JOB SEARCH SOURCES             INTERESTED INDUSTRIES  \
# 0                  Employee Referrals                          Commerce
# 1                        Social media               Technology Industry
# 2                        Social media                       Oil and gas
# ...

# %%
dfu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 21 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   GENDER                                            80 non-null     object
#  1   AGE RANGE                                         80 non-null     object
#  2   EDUCATION LEVEL                                   80 non-null     object
#  3   JOB BOARD USAGE FREQUENCY                         80 non-null     object
#  4   USED JOB BOARDS                                   80 non-null     object
#  5   OTHER JOB SEARCH SOURCES                          80 non-null     object
#  6   INTERESTED INDUSTRIES                             80 non-null     object
#  7   JOB BOARD SUCCESS RATING                          80 non-null     int64
#  8   SUCCESSFUL JOB BOARD EMPLOYMENT                   80 non-null     object
# ...

# %%
dfu.describe()
# Out:
#        JOB BOARD SUCCESS RATING  JOB BOARD EFFICIENCY RATING  \
# count                 80.000000                    80.000000
# mean                   2.950000                     4.962500
# std                    1.200211                     2.280594
# min                    1.000000                     1.000000
# 25%                    2.000000                     3.000000
# 50%                    3.000000                     5.000000
# 75%                    4.000000                     7.000000
# max                    5.000000                    10.000000
#
#        JOB POSTING QUALITY RATING  LIKELIHOOD TO RECOMMEND JOB BOARDS  \
# count                   80.000000                           80.000000
# mean                     4.962500                            5.462500
# std                      1.983755                            2.428438
# min                      1.000000                            1.000000
# ...

# %%
dfu.corr()
# Out:
# C:\Users\AgoCoded\AppData\Local\Temp\ipykernel_11052\3133343733.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dfu.corr()
#                                     JOB BOARD SUCCESS RATING  \
# JOB BOARD SUCCESS RATING                            1.000000
# JOB BOARD EFFICIENCY RATING                        -0.005318
# JOB POSTING QUALITY RATING                         -0.149660
# LIKELIHOOD TO RECOMMEND JOB BOARDS                 -0.078825
# UN_NAMED20                                               NaN
#
#                                     JOB BOARD EFFICIENCY RATING  \
# JOB BOARD SUCCESS RATING                              -0.005318
# JOB BOARD EFFICIENCY RATING                            1.000000
# JOB POSTING QUALITY RATING                             0.791500
# ...

# %% [markdown]
# There is good correlation between "JOB BOARD EFFICIENCY RATING" and "JOB POSTING QUALITY RATING" , "LIKELIHOOD TO RECOMMEND JOB BOARDS"

# %% [markdown]
# # Visualizations

# %%
plt.figure(figsize=(12,4),dpi=150)
sns.countplot(data=dfu,x='GENDER',)
# Out:
# <Axes: xlabel='GENDER', ylabel='count'>

# %%
plt.figure(figsize=(12,4),dpi=150)
sns.countplot(data=dfu,x='AGE RANGE',palette='magma')

plt.title("Visualization of Age Range")
# Out:
# Text(0.5, 1.0, 'Visualization of Age Range')

# %% [markdown]
# **Job Board Sources**

# %%
plt.figure(figsize=(12,4),dpi=150)
sns.countplot(data=dfu,x='OTHER JOB SEARCH SOURCES',palette='magma')
plt.xticks(rotation=90)
plt.title("Visualization of Job Board Sources")
# Out:
# Text(0.5, 1.0, 'Visualization of Job Board Sources')

# %% [markdown]
# **Educational Levels**

# %%
plt.figure(figsize=(12, 4), dpi=150)
ax = sns.countplot(data=dfu, x='EDUCATION LEVEL')
plt.xticks(rotation=90)
# Out:
# (array([0, 1, 2, 3, 4, 5, 6]),
#  [Text(0, 0, "Bachelor's Degree"),
#   Text(1, 0, 'High School Diploma/GED'),
#   Text(2, 0, "Master's Degree"),
#   Text(3, 0, 'Associate Degree/Diploma'),
#   Text(4, 0, 'Doctorate/Ph.D.'),
#   Text(5, 0, 'SHS'),
#   Text(6, 0, 'Higher National Diploma')])

# %% [markdown]
# # Board Ratings

# %%
# Group the data by 'USED JOB BOARDS' and calculate the average rating
average_ratings = dfu.groupby('USED JOB BOARDS')['JOB BOARD SUCCESS RATING', 'JOB BOARD EFFICIENCY RATING', 'JOB POSTING QUALITY RATING', 'LIKELIHOOD TO RECOMMEND JOB BOARDS'].mean().reset_index()

average_ratings
# Out:
# C:\Users\AgoCoded\AppData\Local\Temp\ipykernel_11052\734196991.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   average_ratings = dfu.groupby('USED JOB BOARDS')['JOB BOARD SUCCESS RATING', 'JOB BOARD EFFICIENCY RATING', 'JOB POSTING QUALITY RATING', 'LIKELIHOOD TO RECOMMEND JOB BOARDS'].mean().reset_index()
#                                      USED JOB BOARDS  \
# 0            Bright Network and Opportunities Corner
# 1                                                 IG
# 2                                          Jobberman
# 3                                           LinkedIn
# 4                              Monster, Indeed, Dice
# 5                                               None
# 6  None. I normally do direct contact with companies
# 7                                 Whatsapp platforms
#
#    JOB BOARD SUCCESS RATING  JOB BOARD EFFICIENCY RATING  \
# ...

# %%
# Create a bar plot using Seaborn
plt.figure(figsize=(12, 6))
sns.barplot(data=average_ratings, x='USED JOB BOARDS', y='JOB BOARD SUCCESS RATING', palette='viridis')
plt.title('Average Job Board Success Rating')
plt.xticks(rotation=90)  # Rotate x-labels for readability
# Out:
# (array([0, 1, 2, 3, 4, 5, 6, 7]),
#  [Text(0, 0, 'Bright Network and Opportunities Corner'),
#   Text(1, 0, 'IG'),
#   Text(2, 0, 'Jobberman'),
#   Text(3, 0, 'LinkedIn'),
#   Text(4, 0, 'Monster, Indeed, Dice'),
#   Text(5, 0, 'None'),
#   Text(6, 0, 'None. I normally do direct contact with companies'),
#   Text(7, 0, 'Whatsapp platforms')])

# %%
# Create a bar plot using Seaborn
plt.figure(figsize=(12, 6))
sns.barplot(data=average_ratings, x='USED JOB BOARDS', y='JOB BOARD EFFICIENCY RATING', palette='viridis')
plt.title('Average Job Board Efficiency Rating')
plt.xticks(rotation=90)  # Rotate x-labels for readability
# Out:
# (array([0, 1, 2, 3, 4, 5, 6, 7]),
#  [Text(0, 0, 'Bright Network and Opportunities Corner'),
#   Text(1, 0, 'IG'),
#   Text(2, 0, 'Jobberman'),
#   Text(3, 0, 'LinkedIn'),
#   Text(4, 0, 'Monster, Indeed, Dice'),
#   Text(5, 0, 'None'),
#   Text(6, 0, 'None. I normally do direct contact with companies'),
#   Text(7, 0, 'Whatsapp platforms')])

# %%
# Create a bar plot using Seaborn
plt.figure(figsize=(12, 6))
sns.barplot(data=average_ratings, x='USED JOB BOARDS', y='JOB POSTING QUALITY RATING', palette='viridis')
plt.title('Average Job Board Quality Rating')
plt.xticks(rotation=90)  # Rotate x-labels for readability
# Out:
# (array([0, 1, 2, 3, 4, 5, 6, 7]),
#  [Text(0, 0, 'Bright Network and Opportunities Corner'),
#   Text(1, 0, 'IG'),
#   Text(2, 0, 'Jobberman'),
#   Text(3, 0, 'LinkedIn'),
#   Text(4, 0, 'Monster, Indeed, Dice'),
#   Text(5, 0, 'None'),
#   Text(6, 0, 'None. I normally do direct contact with companies'),
#   Text(7, 0, 'Whatsapp platforms')])

# %%
# Create a bar plot using Seaborn
plt.figure(figsize=(12, 6))
sns.barplot(data=average_ratings, x='USED JOB BOARDS', y='LIKELIHOOD TO RECOMMEND JOB BOARDS', palette='viridis')
plt.title('Average Job Board Recommedation Rating')
plt.xticks(rotation=90)  # Rotate x-labels for readability
# Out:
# (array([0, 1, 2, 3, 4, 5, 6, 7]),
#  [Text(0, 0, 'Bright Network and Opportunities Corner'),
#   Text(1, 0, 'IG'),
#   Text(2, 0, 'Jobberman'),
#   Text(3, 0, 'LinkedIn'),
#   Text(4, 0, 'Monster, Indeed, Dice'),
#   Text(5, 0, 'None'),
#   Text(6, 0, 'None. I normally do direct contact with companies'),
#   Text(7, 0, 'Whatsapp platforms')])

# %% [markdown]
# **Usage**

# %%
plt.figure(figsize=(12, 4), dpi=150)
sns.countplot(data=dfu, x="JOB BOARD USAGE FREQUENCY")
plt.title("Job Board Usage")
# Out:
# Text(0.5, 1.0, 'Job Board Usage')

# %% [markdown]
# # Age Range

# %%
dfu
# Out:
#     GENDER AGE RANGE          EDUCATION LEVEL JOB BOARD USAGE FREQUENCY  \
# 0     Male     25-34        Bachelor's Degree           Rarely or never
# 1     Male     18-24        Bachelor's Degree                    Weekly
# 2   Female     18-24        Bachelor's Degree           Rarely or never
# 3   Female     18-24        Bachelor's Degree           Rarely or never
# 4     Male     18-24        Bachelor's Degree                     Daily
# ..     ...       ...                      ...                       ...
# 75    Male     25-34        Bachelor's Degree                   Monthly
# 76    Male     25-34  Higher National Diploma                     Daily
# 77  Female     18-24        Bachelor's Degree           Rarely or never
# 78  Female     18-24        Bachelor's Degree           Rarely or never
# 79    Male     25-34        Bachelor's Degree                    Weekly
#
#                             USED JOB BOARDS  \
# 0                                  LinkedIn
# ...

# %%
# Group the data by 'USED JOB BOARDS' and calculate the average rating
average_rate = dfu.groupby('AGE RANGE')['JOB BOARD SUCCESS RATING', 'JOB BOARD EFFICIENCY RATING', 'JOB POSTING QUALITY RATING', 'LIKELIHOOD TO RECOMMEND JOB BOARDS'].mean().reset_index()

average_rate
# Out:
# C:\Users\AgoCoded\AppData\Local\Temp\ipykernel_11052\2796305147.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   average_rate = dfu.groupby('AGE RANGE')['JOB BOARD SUCCESS RATING', 'JOB BOARD EFFICIENCY RATING', 'JOB POSTING QUALITY RATING', 'LIKELIHOOD TO RECOMMEND JOB BOARDS'].mean().reset_index()
#   AGE RANGE  JOB BOARD SUCCESS RATING  JOB BOARD EFFICIENCY RATING  \
# 0     18-24                  3.170732                     4.414634
# 1     25-34                  2.800000                     6.100000
# 2     35-44                  1.833333                     4.166667
# 3     45-54                  3.666667                     2.666667
#
#    JOB POSTING QUALITY RATING  LIKELIHOOD TO RECOMMEND JOB BOARDS
# 0                    4.634146                            5.146341
# 1                    5.766667                            6.266667
# ...

# %%
plt.figure(figsize=(12, 4), dpi=150)
sns.barplot(data=average_rate,x='AGE RANGE', y='LIKELIHOOD TO RECOMMEND JOB BOARDS')
# Out:
# <Axes: xlabel='AGE RANGE', ylabel='LIKELIHOOD TO RECOMMEND JOB BOARDS'>
